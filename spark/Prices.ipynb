# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType
from pyspark.sql.functions import input_file_name
import re

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://lz-dataproc-m.us-central1-c.c.lz-bigdata.internal:40655">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# %%time
#sdf_prices = spark.read.format("csv").option("header","true").load("gs://lz-prices-csv/*.csv")
sdf_prices = spark.read.csv("gs://lz-prices-csv/*.csv", header=True, inferSchema= True, sep=';')
# Out:
# CPU times: user 56.1 ms, sys: 6.99 ms, total: 63.1 ms
# Wall time: 42.2 s

# %%
# Define a UDF to extract the date from the filename
def extract_date_from_filename(filename):
    pattern = r'(\d{4})(\d{2})(\d{2})'
    match = re.search(pattern, filename)
    if match:
        year = match.group(1)
        month = match.group(2)
        day = match.group(3)
        return f"{year}-{month}-{day}"
    else:
        return None

# Register the UDF
extract_date_udf = udf(extract_date_from_filename, StringType())

# Extract date with UDF
sdf_prices = sdf_prices.withColumn("date", extract_date_udf(input_file_name()))

# %%
sdf_prices.select("name", "date").toPandas()
# Out:
#                                           name        date
# 0                          uCLEAN ADL-1420 EHP  2023-06-24
# 1                                 siaspeed1950  2023-06-24
# 2                                  metaBOX 215  2023-06-24
# 3                        metaBOX 118 Organizer  2023-06-24
# 4                                iPulse H-1635  2023-06-24
# ...                                        ...         ...
# 45475    3M 51370 737U Hookit disc P120 150 mm  2023-07-17
# 45476  3M 31651 Cubitron 150mm P120 - 50 stuks  2023-07-17
# 45477   19-TLG. HSS-CO SPIRALBOHRERSET, PROBOX  2023-07-17
# 45478                            1230 M AFC EU  2023-07-17
# 45479                        1025 L PC EU 230V  2023-07-17
#
# [45480 rows x 2 columns]

# %%
columns = ["brand", "name", "date", "Median (Price)", "contorion", "werkzeugstore24", "Min shop"]

# %%
sdf_prices.printSchema()
# Out:
# root
#  |--  key: string (nullable = true)
#  |-- EAN: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- group: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- PI product link: string (nullable = true)
#  |-- Median (Price): string (nullable = true)
#  |-- cheapest shop name: string (nullable = true)
#  |-- cheapest shop shipping time: string (nullable = true)
#  |-- cheapest shop availability: string (nullable = true)
#  |-- info: string (nullable = true)
#  |-- total number of offers: string (nullable = true)
#  |-- price difference: string (nullable = true)
#  |-- enableMarketplacesColumn: string (nullable = true)
#  |-- google.de Name: string (nullable = true)
#  |-- google.de Url: string (nullable = true)
#  |-- idealo.de Name: string (nullable = true)
#  |-- idealo.de Url: string (nullable = true)
#  |-- amazon.de Name: string (nullable = true)
#  |-- amazon.de Url: string (nullable = true)
#  |-- kaufland.de Name: string (nullable = true)
#  |-- kaufland.de Url: string (nullable = true)
#  |-- Preis: string (nullable = true)
#  |-- Unnamed: 24: string (nullable = true)
#  |-- % zum min. (Big Players): string (nullable = true)
#  |-- % zum Durchschnitt (Big Players): string (nullable = true)
#  |-- % zum max. (Big Players): string (nullable = true)
#  |-- Unnamed: 28: string (nullable = true)
#  |-- Min. Angebot (Big Players): string (nullable = true)
#  |-- Min shop: string (nullable = true)
#  |-- Lieferzeit: string (nullable = true)
#  |-- Verfügbarkeit: string (nullable = true)
#  |-- Durchschnitt (Big Players): string (nullable = true)
#  |-- Max. Angebot (Big Players): string (nullable = true)
#  |-- Unnamed: 35: string (nullable = true)
#  |-- manomano: string (nullable = true)
#  |-- manomano Delta: string (nullable = true)
#  |-- kaufland: string (nullable = true)
#  |-- kaufland Delta: string (nullable = true)
#  |-- contorion: string (nullable = true)
#  |-- contorion Delta: string (nullable = true)
#  |-- toolnation: string (nullable = true)
#  |-- toolnation Delta: string (nullable = true)
#  |-- galaxus: string (nullable = true)
#  |-- galaxus Delta: string (nullable = true)
#  |-- rubart: string (nullable = true)
#  |-- rubart Delta: string (nullable = true)
#  |-- ebay: string (nullable = true)
#  |-- ebay Delta: string (nullable = true)
#  |-- amazon: string (nullable = true)
#  |-- amazon Delta: string (nullable = true)
#  |-- otto: string (nullable = true)
#  |-- otto Delta: string (nullable = true)
#  |-- toolineo: string (nullable = true)
#  |-- toolineo Delta: string (nullable = true)
#  |-- rotopino: string (nullable = true)
#  |-- rotopino Delta: string (nullable = true)
#  |-- toolbrothers: string (nullable = true)
#  |-- toolbrothers Delta: string (nullable = true)
#  |-- shop.schreinersache: string (nullable = true)
#  |-- shop.schreinersache Delta: string (nullable = true)
#  |-- bueromarkt-ag: string (nullable = true)
#  |-- bueromarkt-ag Delta: string (nullable = true)
#  |-- svh24: string (nullable = true)
#  |-- svh24 Delta: string (nullable = true)
#  |-- reidl: string (nullable = true)
#  |-- reidl Delta: string (nullable = true)
#  |-- gotools: string (nullable = true)
#  |-- gotools Delta: string (nullable = true)
#  |-- tuul.zone: string (nullable = true)
#  |-- tuul.zone Delta: string (nullable = true)
#  |-- böttcher-ag: string (nullable = true)
#  |-- böttcher-ag Delta: string (nullable = true)
#  |-- mima: string (nullable = true)
#  |-- mima Delta: string (nullable = true)
#  |-- werkzeugstore24: string (nullable = true)
#  |-- werkzeugstore24 Delta: string (nullable = true)
#  |-- conrad: string (nullable = true)
#  |-- conrad Delta: string (nullable = true)
#  |-- digitalo: string (nullable = true)
#  |-- digitalo Delta: string (nullable = true)
#  |-- voelkner: string (nullable = true)
#  |-- voelkner Delta: string (nullable = true)
#  |-- jacob: string (nullable = true)
#  |-- jacob Delta: string (nullable = true)
#  |-- ach-shop: string (nullable = true)
#  |-- ach-shop Delta: string (nullable = true)
#  |-- ach autocolor: string (nullable = true)
#  |-- ach autocolor Delta: string (nullable = true)
#  |-- bauportal24h: string (nullable = true)
#  |-- bauportal24h Delta: string (nullable = true)
#  |-- smdv: string (nullable = true)
#  |-- smdv Delta: string (nullable = true)
#  |-- amazon mp: string (nullable = true)
#  |-- amazon mp Delta: string (nullable = true)
#  |-- proshop: string (nullable = true)
#  |-- proshop Delta: string (nullable = true)
#  |-- hammerarzt: string (nullable = true)
#  |-- hammerarzt Delta: string (nullable = true)
#  |-- voelkner.de (marktplatzhändler): string (nullable = true)
#  |-- voelkner.de (marktplatzhändler) Delta: string (nullable = true)
#  |-- alternate: string (nullable = true)
#  |-- alternate Delta: string (nullable = true)
#  |-- b & g maschinenprofi: string (nullable = true)
#  |-- b & g maschinenprofi Delta: string (nullable = true)
#  |-- shop.werkzeugmarkt24: string (nullable = true)
#  |-- shop.werkzeugmarkt24 Delta: string (nullable = true)
#  |-- amazon marketplace: string (nullable = true)
#  |-- amazon marketplace Delta: string (nullable = true)
#  |-- profishop: string (nullable = true)
#  |-- profishop Delta: string (nullable = true)
#  |-- kirchner24: string (nullable = true)
#  |-- kirchner24 Delta: string (nullable = true)
#  |-- koempf24: string (nullable = true)
#  |-- koempf24 Delta: string (nullable = true)
#  |-- meinhausshop: string (nullable = true)
#  |-- meinhausshop Delta: string (nullable = true)
#  |-- misterworker: string (nullable = true)
#  |-- misterworker Delta: string (nullable = true)
#  |-- profi-store24: string (nullable = true)
#  |-- profi-store24 Delta: string (nullable = true)
#  |-- handwerkerstore24: string (nullable = true)
#  |-- handwerkerstore24 Delta: string (nullable = true)
#  |-- dittmar-werkzeuge: string (nullable = true)
#  |-- dittmar-werkzeuge Delta: string (nullable = true)
#  |-- ott jmr beschlagswelt: string (nullable = true)
#  |-- ott jmr beschlagswelt Delta: string (nullable = true)
#  |-- banemo: string (nullable = true)
#  |-- banemo Delta: string (nullable = true)
#  |-- computeruniverse: string (nullable = true)
#  |-- computeruniverse Delta: string (nullable = true)
#  |-- power-tools: string (nullable = true)
#  |-- power-tools Delta: string (nullable = true)
#  |-- voelkner.de - voelkner: string (nullable = true)
#  |-- voelkner.de - voelkner Delta: string (nullable = true)
#  |-- alles-mit-stecker: string (nullable = true)
#  |-- alles-mit-stecker Delta: string (nullable = true)
#  |-- ams-elektro: string (nullable = true)
#  |-- ams-elektro Delta: string (nullable = true)
#  |-- cbdirekt: string (nullable = true)
#  |-- cbdirekt Delta: string (nullable = true)
#  |-- schreinersache: string (nullable = true)
#  |-- schreinersache Delta: string (nullable = true)
#  |-- mioga: string (nullable = true)
#  |-- mioga Delta: string (nullable = true)
#  |-- baumarkteu: string (nullable = true)
#  |-- baumarkteu Delta: string (nullable = true)
#  |-- achhammer: string (nullable = true)
#  |-- achhammer Delta: string (nullable = true)
#  |-- technikdirekt: string (nullable = true)
#  |-- technikdirekt Delta: string (nullable = true)
#  |-- wbv24: string (nullable = true)
#  |-- wbv24 Delta: string (nullable = true)
#  |-- shop.haeberlin-maschinen: string (nullable = true)
#  |-- shop.haeberlin-maschinen Delta: string (nullable = true)
#  |-- elektrowerkzeug-shop: string (nullable = true)
#  |-- elektrowerkzeug-shop Delta: string (nullable = true)
#  |-- layer-grosshandel: string (nullable = true)
#  |-- layer-grosshandel Delta: string (nullable = true)
#  |-- heiz24: string (nullable = true)
#  |-- heiz24 Delta: string (nullable = true)
#  |-- immex-werkzeuge: string (nullable = true)
#  |-- immex-werkzeuge Delta: string (nullable = true)
#  |-- heimwerkerprofis: string (nullable = true)
#  |-- heimwerkerprofis Delta: string (nullable = true)
#  |-- klokow-gmbh: string (nullable = true)
#  |-- klokow-gmbh Delta: string (nullable = true)
#  |-- bauhaus: string (nullable = true)
#  |-- bauhaus Delta: string (nullable = true)
#  |-- koch-mannes: string (nullable = true)
#  |-- koch-mannes Delta: string (nullable = true)
#  |-- koestner-shop: string (nullable = true)
#  |-- koestner-shop Delta: string (nullable = true)
#  |-- tooler: string (nullable = true)
#  |-- tooler Delta: string (nullable = true)
#  |-- leitermann: string (nullable = true)
#  |-- leitermann Delta: string (nullable = true)
#  |-- fleischmann-werkzeuge: string (nullable = true)
#  |-- fleischmann-werkzeuge Delta: string (nullable = true)
#  |-- hornbach: string (nullable = true)
#  |-- hornbach Delta: string (nullable = true)
#  |-- werkstatt-king: string (nullable = true)
#  |-- werkstatt-king Delta: string (nullable = true)
#  |-- alango: string (nullable = true)
#  |-- alango Delta: string (nullable = true)
#  |-- obi: string (nullable = true)
#  |-- obi Delta: string (nullable = true)
#  |-- kochfreiburg: string (nullable = true)
#  |-- kochfreiburg Delta: string (nullable = true)
#  |-- werkzeugmarkt24: string (nullable = true)
#  |-- werkzeugmarkt24 Delta: string (nullable = true)
#  |-- werkzeug-guenstig.eu: string (nullable = true)
#  |-- werkzeug-guenstig.eu Delta: string (nullable = true)
#  |-- baur versand: string (nullable = true)
#  |-- baur versand Delta: string (nullable = true)
#  |-- svh handels-gmbh: string (nullable = true)
#  |-- svh handels-gmbh Delta: string (nullable = true)
#  |-- galaxus.de (marktplatzhändler): string (nullable = true)
#  |-- galaxus.de (marktplatzhändler) Delta: string (nullable = true)
#  |-- lefeld: string (nullable = true)
#  |-- lefeld Delta: string (nullable = true)
#  |-- laets: string (nullable = true)
#  |-- laets Delta: string (nullable = true)
#  |-- wolf-online-shop: string (nullable = true)
#  |-- wolf-online-shop Delta: string (nullable = true)
#  |-- eisen-pfeiffer: string (nullable = true)
#  |-- eisen-pfeiffer Delta: string (nullable = true)
#  |-- maschinenhandel meyer: string (nullable = true)
#  |-- maschinenhandel meyer Delta: string (nullable = true)
#  |-- banemo - rund ums haus: string (nullable = true)
#  |-- banemo - rund ums haus Delta: string (nullable = true)
#  |-- colorbase: string (nullable = true)
#  |-- colorbase Delta: string (nullable = true)
#  |-- holz-metall.info: string (nullable = true)
#  |-- holz-metall.info Delta: string (nullable = true)
#  |-- j-kesselshop: string (nullable = true)
#  |-- j-kesselshop Delta: string (nullable = true)
#  |-- reidl gmbh & co. kg: string (nullable = true)
#  |-- reidl gmbh & co. kg Delta: string (nullable = true)
#  |-- bueroshop24: string (nullable = true)
#  |-- bueroshop24 Delta: string (nullable = true)
#  |-- 0815.eu: string (nullable = true)
#  |-- 0815.eu Delta: string (nullable = true)
#  |-- price-guard: string (nullable = true)
#  |-- price-guard Delta: string (nullable = true)
#  |-- dinotech e.k., händler & versand aus deutschland: string (nullable = true)
#  |-- dinotech e.k., händler & versand aus deutschland Delta: string (nullable = true)
#  |-- art-tec-tools: string (nullable = true)
#  |-- art-tec-tools Delta: string (nullable = true)
#  |-- smartgoods: string (nullable = true)
#  |-- smartgoods Delta: string (nullable = true)
#  |-- werkzeugfundgrube: string (nullable = true)
#  |-- werkzeugfundgrube Delta: string (nullable = true)
#  |-- etoh24: string (nullable = true)
#  |-- etoh24 Delta: string (nullable = true)
#  |-- griffbereit24: string (nullable = true)
#  |-- griffbereit24 Delta: string (nullable = true)
#  |-- hagebau: string (nullable = true)
#  |-- hagebau Delta: string (nullable = true)
#  |-- ws4you.shop: string (nullable = true)
#  |-- ws4you.shop Delta: string (nullable = true)
#  |-- ibb-shop24: string (nullable = true)
#  |-- ibb-shop24 Delta: string (nullable = true)
#  |-- biebrach morgenstern: string (nullable = true)
#  |-- biebrach morgenstern Delta: string (nullable = true)
#  |-- metro.de/marktplatz: string (nullable = true)
#  |-- metro.de/marktplatz Delta: string (nullable = true)
#  |-- dienemann-bremen: string (nullable = true)
#  |-- dienemann-bremen Delta: string (nullable = true)
#  |-- toolfox.shop (de): string (nullable = true)
#  |-- toolfox.shop (de) Delta: string (nullable = true)
#  |-- dönges: string (nullable = true)
#  |-- dönges Delta: string (nullable = true)
#  |-- raiffeisen baustoffe: string (nullable = true)
#  |-- raiffeisen baustoffe Delta: string (nullable = true)
#  |-- toolshop: string (nullable = true)
#  |-- toolshop Delta: string (nullable = true)
#  |-- passiontec: string (nullable = true)
#  |-- passiontec Delta: string (nullable = true)
#  |-- westfalia: string (nullable = true)
#  |-- westfalia Delta: string (nullable = true)
#  |-- kaufland.de - dinotech: string (nullable = true)
#  |-- kaufland.de - dinotech Delta: string (nullable = true)
#  |-- electronic4you: string (nullable = true)
#  |-- electronic4you Delta: string (nullable = true)
#  |-- baur: string (nullable = true)
#  |-- baur Delta: string (nullable = true)
#  |-- cw-mobile: string (nullable = true)
#  |-- cw-mobile Delta: string (nullable = true)
#  |-- kws-tools: string (nullable = true)
#  |-- kws-tools Delta: string (nullable = true)
#  |-- buecher: string (nullable = true)
#  |-- buecher Delta: string (nullable = true)
#  |-- bricoinn: string (nullable = true)
#  |-- bricoinn Delta: string (nullable = true)
#  |-- industriecenter.net: string (nullable = true)
#  |-- industriecenter.net Delta: string (nullable = true)
#  |-- toom: string (nullable = true)
#  |-- toom Delta: string (nullable = true)
#  |-- mdm tools: string (nullable = true)
#  |-- mdm tools Delta: string (nullable = true)
#  |-- amazon retourenkauf: string (nullable = true)
#  |-- amazon retourenkauf Delta: string (nullable = true)
#  |-- rubart gmbh: string (nullable = true)
#  |-- rubart gmbh Delta: string (nullable = true)
#  |-- gartengeraete-onlineshop: string (nullable = true)
#  |-- gartengeraete-onlineshop Delta: string (nullable = true)
#  |-- kaufland.de - svh24: string (nullable = true)
#  |-- kaufland.de - svh24 Delta: string (nullable = true)
#  |-- electronic4you deutschland: string (nullable = true)
#  |-- electronic4you deutschland Delta: string (nullable = true)
#  |-- festool: string (nullable = true)
#  |-- festool Delta: string (nullable = true)
#  |-- markenbaumarkt24: string (nullable = true)
#  |-- markenbaumarkt24 Delta: string (nullable = true)
#  |-- toom baumarkt: string (nullable = true)
#  |-- toom baumarkt Delta: string (nullable = true)
#  |-- aw-tools: string (nullable = true)
#  |-- aw-tools Delta: string (nullable = true)
#  |-- otto-office: string (nullable = true)
#  |-- otto-office Delta: string (nullable = true)
#  |-- metro: string (nullable = true)
#  |-- metro Delta: string (nullable = true)
#  |-- shop.maingau-energie: string (nullable = true)
#  |-- shop.maingau-energie Delta: string (nullable = true)
#  |-- drivewerk: string (nullable = true)
#  |-- drivewerk Delta: string (nullable = true)
#  |-- elektro4000: string (nullable = true)
#  |-- elektro4000 Delta: string (nullable = true)
#  |-- mytvshop: string (nullable = true)
#  |-- mytvshop Delta: string (nullable = true)
#  |-- bol: string (nullable = true)
#  |-- bol Delta: string (nullable = true)
#  |-- calypsotech: string (nullable = true)
#  |-- calypsotech Delta: string (nullable = true)
#  |-- juramondo: string (nullable = true)
#  |-- juramondo Delta: string (nullable = true)
#  |-- hoffmann-group: string (nullable = true)
#  |-- hoffmann-group Delta: string (nullable = true)
#  |-- b2b-discount: string (nullable = true)
#  |-- b2b-discount Delta: string (nullable = true)
#  |-- gotools_germany: string (nullable = true)
#  |-- gotools_germany Delta: string (nullable = true)
#  |-- maingau shop: string (nullable = true)
#  |-- maingau shop Delta: string (nullable = true)
#  |-- toolz4you: string (nullable = true)
#  |-- toolz4you Delta: string (nullable = true)
#  |-- inn-tools: string (nullable = true)
#  |-- inn-tools Delta: string (nullable = true)
#  |-- comstern: string (nullable = true)
#  |-- comstern Delta: string (nullable = true)
#  |-- barax: string (nullable = true)
#  |-- barax Delta: string (nullable = true)
#  |-- expresstools: string (nullable = true)
#  |-- expresstools Delta: string (nullable = true)
#  |-- onlinedeal24, onlinedeal24: string (nullable = true)
#  |-- onlinedeal24, onlinedeal24 Delta: string (nullable = true)
#  |-- shop.doenges-rs: string (nullable = true)
#  |-- shop.doenges-rs Delta: string (nullable = true)
#  |-- blumenbeckerindustriebedarf gmbh: string (nullable = true)
#  |-- blumenbeckerindustriebedarf gmbh Delta: string (nullable = true)
#  |-- werkzeugbilliger: string (nullable = true)
#  |-- werkzeugbilliger Delta: string (nullable = true)
#  |-- tooltown: string (nullable = true)
#  |-- tooltown Delta: string (nullable = true)
#  |-- online-werkzeughandel: string (nullable = true)
#  |-- online-werkzeughandel Delta: string (nullable = true)
#  |-- yellowcrab: string (nullable = true)
#  |-- yellowcrab Delta: string (nullable = true)
#  |-- verkter de: string (nullable = true)
#  |-- verkter de Delta: string (nullable = true)
#  |-- maschinenwelt: string (nullable = true)
#  |-- maschinenwelt Delta: string (nullable = true)
#  |-- tech-tiger: string (nullable = true)
#  |-- tech-tiger Delta: string (nullable = true)
#  |-- coolblue: string (nullable = true)
#  |-- coolblue Delta: string (nullable = true)
#  |-- dictum: string (nullable = true)
#  |-- dictum Delta: string (nullable = true)
#  |-- rs deutschland: string (nullable = true)
#  |-- rs deutschland Delta: string (nullable = true)
#  |-- viking: string (nullable = true)
#  |-- viking Delta: string (nullable = true)
#  |-- derwerkzeugprofi24: string (nullable = true)
#  |-- derwerkzeugprofi24 Delta: string (nullable = true)
#  |-- tecfox: string (nullable = true)
#  |-- tecfox Delta: string (nullable = true)
#  |-- adt diamantwerkzeuge: string (nullable = true)
#  |-- adt diamantwerkzeuge Delta: string (nullable = true)
#  |-- uhlendorffgmbh: string (nullable = true)
#  |-- uhlendorffgmbh Delta: string (nullable = true)
#  |-- tandmore: string (nullable = true)
#  |-- tandmore Delta: string (nullable = true)
#  |-- bodenhaus: string (nullable = true)
#  |-- bodenhaus Delta: string (nullable = true)
#  |-- asd: string (nullable = true)
#  |-- asd Delta: string (nullable = true)
#  |-- neureiter-shop.at: string (nullable = true)
#  |-- neureiter-shop.at Delta: string (nullable = true)
#  |-- agrodirect.at: string (nullable = true)
#  |-- agrodirect.at Delta: string (nullable = true)
#  |-- werkzeuge4u: string (nullable = true)
#  |-- werkzeuge4u Delta: string (nullable = true)
#  |-- karch-maschinen: string (nullable = true)
#  |-- karch-maschinen Delta: string (nullable = true)
#  |-- kauf-schrauben: string (nullable = true)
#  |-- kauf-schrauben Delta: string (nullable = true)
#  |-- mapadies: string (nullable = true)
#  |-- mapadies Delta: string (nullable = true)
#  |-- eibabo: string (nullable = true)
#  |-- eibabo Delta: string (nullable = true)
#  |-- peachonlinemall: string (nullable = true)
#  |-- peachonlinemall Delta: string (nullable = true)
#  |-- hagebau nadlinger: string (nullable = true)
#  |-- hagebau nadlinger Delta: string (nullable = true)
#  |-- bauxxl: string (nullable = true)
#  |-- bauxxl Delta: string (nullable = true)
#  |-- parfum-for-less: string (nullable = true)
#  |-- parfum-for-less Delta: string (nullable = true)
#  |-- parfuemerie-wilhelm-haas: string (nullable = true)
#  |-- parfuemerie-wilhelm-haas Delta: string (nullable = true)
#  |-- jh-profishop: string (nullable = true)
#  |-- jh-profishop Delta: string (nullable = true)
#  |-- flacon24_ug: string (nullable = true)
#  |-- flacon24_ug Delta: string (nullable = true)
#  |-- wrapup: string (nullable = true)
#  |-- wrapup Delta: string (nullable = true)
#  |-- ssk-schrauben schmid gmbh: string (nullable = true)
#  |-- ssk-schrauben schmid gmbh Delta: string (nullable = true)
#  |-- kaufland.de - kirchner24: string (nullable = true)
#  |-- kaufland.de - kirchner24 Delta: string (nullable = true)
#  |-- fnshop: string (nullable = true)
#  |-- fnshop Delta: string (nullable = true)
#  |-- werkstatt-king (preise inkl. mwst.): string (nullable = true)
#  |-- werkstatt-king (preise inkl. mwst.) Delta: string (nullable = true)
#  |-- deine tante emma: string (nullable = true)
#  |-- deine tante emma Delta: string (nullable = true)
#  |-- büro bedarf thüringen: string (nullable = true)
#  |-- büro bedarf thüringen Delta: string (nullable = true)
#  |-- mein-gartenshop24: string (nullable = true)
#  |-- mein-gartenshop24 Delta: string (nullable = true)
#  |-- octo24: string (nullable = true)
#  |-- octo24 Delta: string (nullable = true)
#  |-- score schleifwerkzeuge: string (nullable = true)
#  |-- score schleifwerkzeuge Delta: string (nullable = true)
#  |-- cbo-de: string (nullable = true)
#  |-- cbo-de Delta: string (nullable = true)
#  |-- fleischmann-werkzeuge-de: string (nullable = true)
#  |-- fleischmann-werkzeuge-de Delta: string (nullable = true)
#  |-- ambitline: string (nullable = true)
#  |-- ambitline Delta: string (nullable = true)
#  |-- giegerich-werkzeuge-shop.de/: string (nullable = true)
#  |-- giegerich-werkzeuge-shop.de/ Delta: string (nullable = true)
#  |-- dinotech: string (nullable = true)
#  |-- dinotech Delta: string (nullable = true)
#  |-- thalia: string (nullable = true)
#  |-- thalia Delta: string (nullable = true)
#  |-- boschettileo: string (nullable = true)
#  |-- boschettileo Delta: string (nullable = true)
#  |-- voelkner.de - voelkner - marktplatz: string (nullable = true)
#  |-- voelkner.de - voelkner - marktplatz Delta: string (nullable = true)
#  |-- deltatecc: string (nullable = true)
#  |-- deltatecc Delta: string (nullable = true)
#  |-- kraso: string (nullable = true)
#  |-- kraso Delta: string (nullable = true)
#  |-- dinotech.werkzeug: string (nullable = true)
#  |-- dinotech.werkzeug Delta: string (nullable = true)
#  |-- hood: string (nullable = true)
#  |-- hood Delta: string (nullable = true)
#  |-- sysgotec: string (nullable = true)
#  |-- sysgotec Delta: string (nullable = true)
#  |-- quelle: string (nullable = true)
#  |-- quelle Delta: string (nullable = true)
#  |-- wagner fachzentrum: string (nullable = true)
#  |-- wagner fachzentrum Delta: string (nullable = true)
#  |-- egger-online: string (nullable = true)
#  |-- egger-online Delta: string (nullable = true)
#  |-- bermaro online shop: string (nullable = true)
#  |-- bermaro online shop Delta: string (nullable = true)
#  |-- emax-haustechnik: string (nullable = true)
#  |-- emax-haustechnik Delta: string (nullable = true)
#  |-- immex-werkzeughandel: string (nullable = true)
#  |-- immex-werkzeughandel Delta: string (nullable = true)
#  |-- powertools germany: string (nullable = true)
#  |-- powertools germany Delta: string (nullable = true)
#  |-- shop-elektrowerkzeuge: string (nullable = true)
#  |-- shop-elektrowerkzeuge Delta: string (nullable = true)
#  |-- aeg-shop-dresden: string (nullable = true)
#  |-- aeg-shop-dresden Delta: string (nullable = true)
#  |-- toolskitchen: string (nullable = true)
#  |-- toolskitchen Delta: string (nullable = true)
#  |-- schipro: string (nullable = true)
#  |-- schipro Delta: string (nullable = true)
#  |-- prosol-farben: string (nullable = true)
#  |-- prosol-farben Delta: string (nullable = true)
#  |-- megatech-shop: string (nullable = true)
#  |-- megatech-shop Delta: string (nullable = true)
#  |-- technik-guenstiger_de: string (nullable = true)
#  |-- technik-guenstiger_de Delta: string (nullable = true)
#  |-- eibmarkt: string (nullable = true)
#  |-- eibmarkt Delta: string (nullable = true)
#  |-- handelsagentur_leiteritz: string (nullable = true)
#  |-- handelsagentur_leiteritz Delta: string (nullable = true)
#  |-- crop: string (nullable = true)
#  |-- crop Delta: string (nullable = true)
#  |-- elektromk: string (nullable = true)
#  |-- elektromk Delta: string (nullable = true)
#  |-- handwerkerpoint: string (nullable = true)
#  |-- handwerkerpoint Delta: string (nullable = true)
#  |-- mach es selbst: string (nullable = true)
#  |-- mach es selbst Delta: string (nullable = true)
#  |-- werkzeugwelt24: string (nullable = true)
#  |-- werkzeugwelt24 Delta: string (nullable = true)
#  |-- befestigungszentrum: string (nullable = true)
#  |-- befestigungszentrum Delta: string (nullable = true)
#  |-- baustoffshop: string (nullable = true)
#  |-- baustoffshop Delta: string (nullable = true)
#  |-- e-bricoshop: string (nullable = true)
#  |-- e-bricoshop Delta: string (nullable = true)
#  |-- diamanttechnik & spezialwerkzeuge galler: string (nullable = true)
#  |-- diamanttechnik & spezialwerkzeuge galler Delta: string (nullable = true)
#  |-- traumpreisfabrik: string (nullable = true)
#  |-- traumpreisfabrik Delta: string (nullable = true)
#  |-- etrona: string (nullable = true)
#  |-- etrona Delta: string (nullable = true)
#  |-- kurfurstgmbh: string (nullable = true)
#  |-- kurfurstgmbh Delta: string (nullable = true)
#  |-- jungheinrich profishop deutschland: string (nullable = true)
#  |-- jungheinrich profishop deutschland Delta: string (nullable = true)
#  |-- elektro-wandelt: string (nullable = true)
#  |-- elektro-wandelt Delta: string (nullable = true)
#  |-- schweisshelden: string (nullable = true)
#  |-- schweisshelden Delta: string (nullable = true)
#  |-- sotel: string (nullable = true)
#  |-- sotel Delta: string (nullable = true)
#  |-- fnwerkzeuge: string (nullable = true)
#  |-- fnwerkzeuge Delta: string (nullable = true)
#  |-- bu gmbh: string (nullable = true)
#  |-- bu gmbh Delta: string (nullable = true)
#  |-- duschking: string (nullable = true)
#  |-- duschking Delta: string (nullable = true)
#  |-- promarco: string (nullable = true)
#  |-- promarco Delta: string (nullable = true)
#  |-- kemmler baustoffe: string (nullable = true)
#  |-- kemmler baustoffe Delta: string (nullable = true)
#  |-- amazon uk: string (nullable = true)
#  |-- amazon uk Delta: string (nullable = true)
#  |-- atala: string (nullable = true)
#  |-- atala Delta: string (nullable = true)
#  |-- werkzeug-guenstig: string (nullable = true)
#  |-- werkzeug-guenstig Delta: string (nullable = true)
#  |-- hms-shop24: string (nullable = true)
#  |-- hms-shop24 Delta: string (nullable = true)
#  |-- autorefinish: string (nullable = true)
#  |-- autorefinish Delta: string (nullable = true)
#  |-- sanitino: string (nullable = true)
#  |-- sanitino Delta: string (nullable = true)
#  |-- euro industry: string (nullable = true)
#  |-- euro industry Delta: string (nullable = true)
#  |-- get online gmbh: string (nullable = true)
#  |-- get online gmbh Delta: string (nullable = true)
#  |-- elektroshopwagner: string (nullable = true)
#  |-- elektroshopwagner Delta: string (nullable = true)
#  |-- se-shop24: string (nullable = true)
#  |-- se-shop24 Delta: string (nullable = true)
#  |-- ejoker_de: string (nullable = true)
#  |-- ejoker_de Delta: string (nullable = true)
#  |-- haus-gartenwelt: string (nullable = true)
#  |-- haus-gartenwelt Delta: string (nullable = true)
#  |-- hausunddach: string (nullable = true)
#  |-- hausunddach Delta: string (nullable = true)
#  |-- stortle: string (nullable = true)
#  |-- stortle Delta: string (nullable = true)
#  |-- marketdeferreteria-de: string (nullable = true)
#  |-- marketdeferreteria-de Delta: string (nullable = true)
#  |-- beschicht: string (nullable = true)
#  |-- beschicht Delta: string (nullable = true)
#  |-- hepeshop: string (nullable = true)
#  |-- hepeshop Delta: string (nullable = true)
#  |-- bauking.suedwestfalen: string (nullable = true)
#  |-- bauking.suedwestfalen Delta: string (nullable = true)
#  |-- allesfuerzuhause: string (nullable = true)
#  |-- allesfuerzuhause Delta: string (nullable = true)
#  |-- hellweg: string (nullable = true)
#  |-- hellweg Delta: string (nullable = true)
#  |-- iclean: string (nullable = true)
#  |-- iclean Delta: string (nullable = true)
#  |-- baywa-baumarkt: string (nullable = true)
#  |-- baywa-baumarkt Delta: string (nullable = true)
#  |-- c-tools24: string (nullable = true)
#  |-- c-tools24 Delta: string (nullable = true)
#  |-- dahle-verbindungstechnik: string (nullable = true)
#  |-- dahle-verbindungstechnik Delta: string (nullable = true)
#  |-- hitseller: string (nullable = true)
#  |-- hitseller Delta: string (nullable = true)
#  |-- www.atala: string (nullable = true)
#  |-- www.atala Delta: string (nullable = true)
#  |-- seyffer.shop: string (nullable = true)
#  |-- seyffer.shop Delta: string (nullable = true)
#  |-- elektrotools: string (nullable = true)
#  |-- elektrotools Delta: string (nullable = true)
#  |-- yellowcrab.tools (de): string (nullable = true)
#  |-- yellowcrab.tools (de) Delta: string (nullable = true)
#  |-- schleiftitan: string (nullable = true)
#  |-- schleiftitan Delta: string (nullable = true)
#  |-- myhobby24-de_ag: string (nullable = true)
#  |-- myhobby24-de_ag Delta: string (nullable = true)
#  |-- autodoc: string (nullable = true)
#  |-- autodoc Delta: string (nullable = true)
#  |-- arndt europadiscount: string (nullable = true)
#  |-- arndt europadiscount Delta: string (nullable = true)
#  |-- mounaco: string (nullable = true)
#  |-- mounaco Delta: string (nullable = true)
#  |-- tuulzone: string (nullable = true)
#  |-- tuulzone Delta: string (nullable = true)
#  |-- tabius: string (nullable = true)
#  |-- tabius Delta: string (nullable = true)
#  |-- marketdeferreteria: string (nullable = true)
#  |-- marketdeferreteria Delta: string (nullable = true)
#  |-- globus-baumarkt: string (nullable = true)
#  |-- globus-baumarkt Delta: string (nullable = true)
#  |-- werkzeugstore: string (nullable = true)
#  |-- werkzeugstore Delta: string (nullable = true)
#  |-- louis-heinsberg: string (nullable = true)
#  |-- louis-heinsberg Delta: string (nullable = true)
#  |-- okluge: string (nullable = true)
#  |-- okluge Delta: string (nullable = true)
#  |-- schwemmer & dorn: string (nullable = true)
#  |-- schwemmer & dorn Delta: string (nullable = true)
#  |-- doenges1903: string (nullable = true)
#  |-- doenges1903 Delta: string (nullable = true)
#  |-- elektro-gaertner: string (nullable = true)
#  |-- elektro-gaertner Delta: string (nullable = true)
#  |-- baulinger: string (nullable = true)
#  |-- baulinger Delta: string (nullable = true)
#  |-- boeckmannshop24: string (nullable = true)
#  |-- boeckmannshop24 Delta: string (nullable = true)
#  |-- willers-shop: string (nullable = true)
#  |-- willers-shop Delta: string (nullable = true)
#  |-- lefeld gmbh & co. kg: string (nullable = true)
#  |-- lefeld gmbh & co. kg Delta: string (nullable = true)
#  |-- mima-de: string (nullable = true)
#  |-- mima-de Delta: string (nullable = true)
#  |-- deine-tante-emma: string (nullable = true)
#  |-- deine-tante-emma Delta: string (nullable = true)
#  |-- bjc tools de: string (nullable = true)
#  |-- bjc tools de Delta: string (nullable = true)
#  |-- grooves-inc.de: string (nullable = true)
#  |-- grooves-inc.de Delta: string (nullable = true)
#  |-- deltatecc gmbh: string (nullable = true)
#  |-- deltatecc gmbh Delta: string (nullable = true)
#  |-- kaufland.de - doenges1903: string (nullable = true)
#  |-- kaufland.de - doenges1903 Delta: string (nullable = true)
#  |-- cas-expert: string (nullable = true)
#  |-- cas-expert Delta: string (nullable = true)
#  |-- glogner-shop: string (nullable = true)
#  |-- glogner-shop Delta: string (nullable = true)
#  |-- tools technik gilges: string (nullable = true)
#  |-- tools technik gilges Delta: string (nullable = true)
#  |-- internetwerkzeug: string (nullable = true)
#  |-- internetwerkzeug Delta: string (nullable = true)
#  |-- baumarktdiscount: string (nullable = true)
#  |-- baumarktdiscount Delta: string (nullable = true)
#  |-- stefan stuht gmbh: string (nullable = true)
#  |-- stefan stuht gmbh Delta: string (nullable = true)
#  |-- btr-tools: string (nullable = true)
#  |-- btr-tools Delta: string (nullable = true)
#  |-- schick24-baumarkt: string (nullable = true)
#  |-- schick24-baumarkt Delta: string (nullable = true)
#  |-- baumarkt bender: string (nullable = true)
#  |-- baumarkt bender Delta: string (nullable = true)
#  |-- myhobby24: string (nullable = true)
#  |-- myhobby24 Delta: string (nullable = true)
#  |-- csv-direct: string (nullable = true)
#  |-- csv-direct Delta: string (nullable = true)
#  |-- kömpf24: string (nullable = true)
#  |-- kömpf24 Delta: string (nullable = true)
#  |-- marini24: string (nullable = true)
#  |-- marini24 Delta: string (nullable = true)
#  |-- gutes-shop: string (nullable = true)
#  |-- gutes-shop Delta: string (nullable = true)
#  |-- alternative-haustechnik: string (nullable = true)
#  |-- alternative-haustechnik Delta: string (nullable = true)
#  |-- mein-online-baumarkt: string (nullable = true)
#  |-- mein-online-baumarkt Delta: string (nullable = true)
#  |-- talk-point: string (nullable = true)
#  |-- talk-point Delta: string (nullable = true)
#  |-- endlich-sicher: string (nullable = true)
#  |-- endlich-sicher Delta: string (nullable = true)
#  |-- wohi: string (nullable = true)
#  |-- wohi Delta: string (nullable = true)
#  |-- koch mannes gmbh: string (nullable = true)
#  |-- koch mannes gmbh Delta: string (nullable = true)
#  |-- kaufland.de - kaufland: string (nullable = true)
#  |-- kaufland.de - kaufland Delta: string (nullable = true)
#  |-- get_online_gmbh: string (nullable = true)
#  |-- get_online_gmbh Delta: string (nullable = true)
#  |-- schick24-baumarkt.de/de/: string (nullable = true)
#  |-- schick24-baumarkt.de/de/ Delta: string (nullable = true)
#  |-- www-arndt-europadiscount-de: string (nullable = true)
#  |-- www-arndt-europadiscount-de Delta: string (nullable = true)
#  |-- roofer24: string (nullable = true)
#  |-- roofer24 Delta: string (nullable = true)
#  |-- conrad_electronic: string (nullable = true)
#  |-- conrad_electronic Delta: string (nullable = true)
#  |-- maschinen grupp gmbh: string (nullable = true)
#  |-- maschinen grupp gmbh Delta: string (nullable = true)
#  |-- aliexpress: string (nullable = true)
#  |-- aliexpress Delta: string (nullable = true)
#  |-- e-joker: string (nullable = true)
#  |-- e-joker Delta: string (nullable = true)
#  |-- m_plus_l: string (nullable = true)
#  |-- m_plus_l Delta: string (nullable = true)
#  |-- schwemmerdorn: string (nullable = true)
#  |-- schwemmerdorn Delta: string (nullable = true)
#  |-- sello24: string (nullable = true)
#  |-- sello24 Delta: string (nullable = true)
#  |-- kirchner-werkzeuge: string (nullable = true)
#  |-- kirchner-werkzeuge Delta: string (nullable = true)
#  |-- onlinedeal24h: string (nullable = true)
#  |-- onlinedeal24h Delta: string (nullable = true)
#  |-- wmv24: string (nullable = true)
#  |-- wmv24 Delta: string (nullable = true)
#  |-- alpa industrielack: string (nullable = true)
#  |-- alpa industrielack Delta: string (nullable = true)
#  |-- kaufland.de - bu-tools: string (nullable = true)
#  |-- kaufland.de - bu-tools Delta: string (nullable = true)
#  |-- bachgmbh: string (nullable = true)
#  |-- bachgmbh Delta: string (nullable = true)
#  |-- stabilo-fachmarkt: string (nullable = true)
#  |-- stabilo-fachmarkt Delta: string (nullable = true)
#  |-- profiwerkzeug24: string (nullable = true)
#  |-- profiwerkzeug24 Delta: string (nullable = true)
#  |-- kaufland.de - maschinen stockert: string (nullable = true)
#  |-- kaufland.de - maschinen stockert Delta: string (nullable = true)
#  |-- koestner-shop-de: string (nullable = true)
#  |-- koestner-shop-de Delta: string (nullable = true)
#  |-- werkfreund-shop: string (nullable = true)
#  |-- werkfreund-shop Delta: string (nullable = true)
#  |-- smartgoods-de: string (nullable = true)
#  |-- smartgoods-de Delta: string (nullable = true)
#  |-- qp24: string (nullable = true)
#  |-- qp24 Delta: string (nullable = true)
#  |-- maschinen stockert: string (nullable = true)
#  |-- maschinen stockert Delta: string (nullable = true)
#  |-- praktiker: string (nullable = true)
#  |-- praktiker Delta: string (nullable = true)
#  |-- todotaladros: string (nullable = true)
#  |-- todotaladros Delta: string (nullable = true)
#  |-- kaufland.de - werkstatt-king: string (nullable = true)
#  |-- kaufland.de - werkstatt-king Delta: string (nullable = true)
#  |-- european tools: string (nullable = true)
#  |-- european tools Delta: string (nullable = true)
#  |-- kaufland.de - daxed: string (nullable = true)
#  |-- kaufland.de - daxed Delta: string (nullable = true)
#  |-- agrar.shop: string (nullable = true)
#  |-- agrar.shop Delta: string (nullable = true)
#  |-- rubart-online: string (nullable = true)
#  |-- rubart-online Delta: string (nullable = true)
#  |-- kaufland.de - schwemmer-dorn: string (nullable = true)
#  |-- kaufland.de - schwemmer-dorn Delta: string (nullable = true)
#  |-- vasalat: string (nullable = true)
#  |-- vasalat Delta: string (nullable = true)
#  |-- ihttimme24: string (nullable = true)
#  |-- ihttimme24 Delta: string (nullable = true)
#  |-- abc professional tools: string (nullable = true)
#  |-- abc professional tools Delta: string (nullable = true)
#  |-- solamate: string (nullable = true)
#  |-- solamate Delta: string (nullable = true)
#  |-- lüttmann: string (nullable = true)
#  |-- lüttmann Delta: string (nullable = true)
#  |-- der handschuhpapst: string (nullable = true)
#  |-- der handschuhpapst Delta: string (nullable = true)
#  |-- holz braun: string (nullable = true)
#  |-- holz braun Delta: string (nullable = true)
#  |-- dichtstoffdepot: string (nullable = true)
#  |-- dichtstoffdepot Delta: string (nullable = true)
#  |-- priz24: string (nullable = true)
#  |-- priz24 Delta: string (nullable = true)
#  |-- die_werkzeugfundgrube: string (nullable = true)
#  |-- die_werkzeugfundgrube Delta: string (nullable = true)
#  |-- elektrotresen: string (nullable = true)
#  |-- elektrotresen Delta: string (nullable = true)
#  |-- xenudo: string (nullable = true)
#  |-- xenudo Delta: string (nullable = true)
#  |-- vipdomo: string (nullable = true)
#  |-- vipdomo Delta: string (nullable = true)
#  |-- aw tools maschinenhandel adalbert wieczorek: string (nullable = true)
#  |-- aw tools maschinenhandel adalbert wieczorek Delta: string (nullable = true)
#  |-- baumarkt-goellnitz: string (nullable = true)
#  |-- baumarkt-goellnitz Delta: string (nullable = true)
#  |-- mediarado: string (nullable = true)
#  |-- mediarado Delta: string (nullable = true)
#  |-- ez-tools gmbh: string (nullable = true)
#  |-- ez-tools gmbh Delta: string (nullable = true)
#  |-- baumarkt göllnitz: string (nullable = true)
#  |-- baumarkt göllnitz Delta: string (nullable = true)
#  |-- toplac: string (nullable = true)
#  |-- toplac Delta: string (nullable = true)
#  |-- loechel_industriebedarf: string (nullable = true)
#  |-- loechel_industriebedarf Delta: string (nullable = true)
#  |-- rotopino de: string (nullable = true)
#  |-- rotopino de Delta: string (nullable = true)
#  |-- hygi: string (nullable = true)
#  |-- hygi Delta: string (nullable = true)
#  |-- alango de: string (nullable = true)
#  |-- alango de Delta: string (nullable = true)
#  |-- autoteiledirekt: string (nullable = true)
#  |-- autoteiledirekt Delta: string (nullable = true)
#  |-- bau- & handwerkerbedarf: string (nullable = true)
#  |-- bau- & handwerkerbedarf Delta: string (nullable = true)
#  |-- meesenburg_grosshandel_kg: string (nullable = true)
#  |-- meesenburg_grosshandel_kg Delta: string (nullable = true)
#  |-- kaufland.de - werkzeug-guenstig: string (nullable = true)
#  |-- kaufland.de - werkzeug-guenstig Delta: string (nullable = true)
#  |-- treise-elektro: string (nullable = true)
#  |-- treise-elektro Delta: string (nullable = true)
#  |-- wertheimer online-shop: string (nullable = true)
#  |-- wertheimer online-shop Delta: string (nullable = true)
#  |-- as-discount: string (nullable = true)
#  |-- as-discount Delta: string (nullable = true)
#  |-- schwemmer-dorn: string (nullable = true)
#  |-- schwemmer-dorn Delta: string (nullable = true)
#  |-- reinigungsberater: string (nullable = true)
#  |-- reinigungsberater Delta: string (nullable = true)
#  |-- luconda: string (nullable = true)
#  |-- luconda Delta: string (nullable = true)
#  |-- haus&dach: string (nullable = true)
#  |-- haus&dach Delta: string (nullable = true)
#  |-- indoostrial: string (nullable = true)
#  |-- indoostrial Delta: string (nullable = true)
#  |-- rs-tools-shop deutscher fachhändler blitz versand: string (nullable = true)
#  |-- rs-tools-shop deutscher fachhändler blitz versand Delta: string (nullable = true)
#  |-- reddogshop: string (nullable = true)
#  |-- reddogshop Delta: string (nullable = true)
#  |-- werkzeughandel-roeder: string (nullable = true)
#  |-- werkzeughandel-roeder Delta: string (nullable = true)
#  |-- agrodirect: string (nullable = true)
#  |-- agrodirect Delta: string (nullable = true)
#  |-- ovolt: string (nullable = true)
#  |-- ovolt Delta: string (nullable = true)
#  |-- yourtools: string (nullable = true)
#  |-- yourtools Delta: string (nullable = true)
#  |-- feramenta: string (nullable = true)
#  |-- feramenta Delta: string (nullable = true)
#  |-- digital-versand-de-online-gmbh: string (nullable = true)
#  |-- digital-versand-de-online-gmbh Delta: string (nullable = true)
#  |-- kuhfuss: string (nullable = true)
#  |-- kuhfuss Delta: string (nullable = true)
#  |-- e-partner-webshop.de/elektroline/: string (nullable = true)
#  |-- e-partner-webshop.de/elektroline/ Delta: string (nullable = true)
#  |-- belion: string (nullable = true)
#  |-- belion Delta: string (nullable = true)
#  |-- brycus-de: string (nullable = true)
#  |-- brycus-de Delta: string (nullable = true)
#  |-- kaufland.de - koestner-shop-de: string (nullable = true)
#  |-- kaufland.de - koestner-shop-de Delta: string (nullable = true)
#  |-- mct multichanneltrade: string (nullable = true)
#  |-- mct multichanneltrade Delta: string (nullable = true)
#  |-- werkstatt king: string (nullable = true)
#  |-- werkstatt king Delta: string (nullable = true)
#  |-- löchel industriebedarf: string (nullable = true)
#  |-- löchel industriebedarf Delta: string (nullable = true)
#  |-- gillet baustoffe: string (nullable = true)
#  |-- gillet baustoffe Delta: string (nullable = true)
#  |-- badplanet.at: string (nullable = true)
#  |-- badplanet.at Delta: string (nullable = true)
#  |-- werkzeug-lotter: string (nullable = true)
#  |-- werkzeug-lotter Delta: string (nullable = true)
#  |-- dalhoff24: string (nullable = true)
#  |-- dalhoff24 Delta: string (nullable = true)
#  |-- abc_professional_tools: string (nullable = true)
#  |-- abc_professional_tools Delta: string (nullable = true)
#  |-- pkwteile: string (nullable = true)
#  |-- pkwteile Delta: string (nullable = true)
#  |-- awa-pro: string (nullable = true)
#  |-- awa-pro Delta: string (nullable = true)
#  |-- pb-c: string (nullable = true)
#  |-- pb-c Delta: string (nullable = true)
#  |-- elbgigant: string (nullable = true)
#  |-- elbgigant Delta: string (nullable = true)
#  |-- tradeinn: string (nullable = true)
#  |-- tradeinn Delta: string (nullable = true)
#  |-- techinn: string (nullable = true)
#  |-- techinn Delta: string (nullable = true)
#  |-- voelkner.de - nilono: string (nullable = true)
#  |-- voelkner.de - nilono Delta: string (nullable = true)
#  |-- ejoker: string (nullable = true)
#  |-- ejoker Delta: string (nullable = true)
#  |-- dastro ® --- einfach. genial. günstig.: string (nullable = true)
#  |-- dastro ® --- einfach. genial. günstig. Delta: string (nullable = true)
#  |-- cbdirekt-shop: string (nullable = true)
#  |-- cbdirekt-shop Delta: string (nullable = true)
#  |-- rg-werkzeuge: string (nullable = true)
#  |-- rg-werkzeuge Delta: string (nullable = true)
#  |-- cheapsell: string (nullable = true)
#  |-- cheapsell Delta: string (nullable = true)
#  |-- 1a-deals: string (nullable = true)
#  |-- 1a-deals Delta: string (nullable = true)
#  |-- voelkner.de - jacob elektronik gmbh: string (nullable = true)
#  |-- voelkner.de - jacob elektronik gmbh Delta: string (nullable = true)
#  |-- qualitätswerkzeuge: string (nullable = true)
#  |-- qualitätswerkzeuge Delta: string (nullable = true)
#  |-- kemmler baustoffe gmbh: string (nullable = true)
#  |-- kemmler baustoffe gmbh Delta: string (nullable = true)
#  |-- ra_trading: string (nullable = true)
#  |-- ra_trading Delta: string (nullable = true)
#  |-- gardenstore: string (nullable = true)
#  |-- gardenstore Delta: string (nullable = true)
#  |-- 2w-shop.eu: string (nullable = true)
#  |-- 2w-shop.eu Delta: string (nullable = true)
#  |-- kaufland.de - xenudo: string (nullable = true)
#  |-- kaufland.de - xenudo Delta: string (nullable = true)
#  |-- hagebau-nadlinger: string (nullable = true)
#  |-- hagebau-nadlinger Delta: string (nullable = true)
#  |-- baulando: string (nullable = true)
#  |-- baulando Delta: string (nullable = true)
#  |-- kk-dichtungstechnik: string (nullable = true)
#  |-- kk-dichtungstechnik Delta: string (nullable = true)
#  |-- kaufland.de - ambitline: string (nullable = true)
#  |-- kaufland.de - ambitline Delta: string (nullable = true)
#  |-- kaufland.de - toldev: string (nullable = true)
#  |-- kaufland.de - toldev Delta: string (nullable = true)
#  |-- elektroradar: string (nullable = true)
#  |-- elektroradar Delta: string (nullable = true)
#  |-- kaufland.de - schipro: string (nullable = true)
#  |-- kaufland.de - schipro Delta: string (nullable = true)
#  |-- baulando-shop: string (nullable = true)
#  |-- baulando-shop Delta: string (nullable = true)
#  |-- primadu: string (nullable = true)
#  |-- primadu Delta: string (nullable = true)
#  |-- twidoo: string (nullable = true)
#  |-- twidoo Delta: string (nullable = true)
#  |-- kaufland.de - juramondo: string (nullable = true)
#  |-- kaufland.de - juramondo Delta: string (nullable = true)
#  |-- bermaro lackierbedarf gmbh: string (nullable = true)
#  |-- bermaro lackierbedarf gmbh Delta: string (nullable = true)
#  |-- praxer: string (nullable = true)
#  |-- praxer Delta: string (nullable = true)
#  |-- mioga warenhandel & service gmbh: string (nullable = true)
#  |-- mioga warenhandel & service gmbh Delta: string (nullable = true)
#  |-- estermann warenhandels gmbh: string (nullable = true)
#  |-- estermann warenhandels gmbh Delta: string (nullable = true)
#  |-- buero-bedarf-thueringen: string (nullable = true)
#  |-- buero-bedarf-thueringen Delta: string (nullable = true)
#  |-- mixamo: string (nullable = true)
#  |-- mixamo Delta: string (nullable = true)
#  |-- hinterseer: string (nullable = true)
#  |-- hinterseer Delta: string (nullable = true)
#  |-- ez-tools: string (nullable = true)
#  |-- ez-tools Delta: string (nullable = true)
#  |-- artifex24 ug: string (nullable = true)
#  |-- artifex24 ug Delta: string (nullable = true)
#  |-- homewoods: string (nullable = true)
#  |-- homewoods Delta: string (nullable = true)
#  |-- sotel (agb und garantiebestimmungen siehe hier): string (nullable = true)
#  |-- sotel (agb und garantiebestimmungen siehe hier) Delta: string (nullable = true)
#  |-- wmb-walther: string (nullable = true)
#  |-- wmb-walther Delta: string (nullable = true)
#  |-- wamster: string (nullable = true)
#  |-- wamster Delta: string (nullable = true)
#  |-- metalzbyt: string (nullable = true)
#  |-- metalzbyt Delta: string (nullable = true)
#  |-- kaufland.de - immex-werkzeughandel: string (nullable = true)
#  |-- kaufland.de - immex-werkzeughandel Delta: string (nullable = true)
#  |-- hbm machines: string (nullable = true)
#  |-- hbm machines Delta: string (nullable = true)
#  |-- fritz-berger: string (nullable = true)
#  |-- fritz-berger Delta: string (nullable = true)
#  |-- fershop: string (nullable = true)
#  |-- fershop Delta: string (nullable = true)
#  |-- beweo-de: string (nullable = true)
#  |-- beweo-de Delta: string (nullable = true)
#  |-- avantrado.shop: string (nullable = true)
#  |-- avantrado.shop Delta: string (nullable = true)
#  |-- fixfast: string (nullable = true)
#  |-- fixfast Delta: string (nullable = true)
#  |-- dammers: string (nullable = true)
#  |-- dammers Delta: string (nullable = true)
#  |-- mein-heimwerkermarkt: string (nullable = true)
#  |-- mein-heimwerkermarkt Delta: string (nullable = true)
#  |-- mersch-reinigungstechnik: string (nullable = true)
#  |-- mersch-reinigungstechnik Delta: string (nullable = true)
#  |-- poliselectro: string (nullable = true)
#  |-- poliselectro Delta: string (nullable = true)
#  |-- lieferung.gratis: string (nullable = true)
#  |-- lieferung.gratis Delta: string (nullable = true)
#  |-- tools pro store global solutions: string (nullable = true)
#  |-- tools pro store global solutions Delta: string (nullable = true)
#  |-- easytronics: string (nullable = true)
#  |-- easytronics Delta: string (nullable = true)
#  |-- kaiserkraft: string (nullable = true)
#  |-- kaiserkraft Delta: string (nullable = true)
#  |-- pro detailing 99: string (nullable = true)
#  |-- pro detailing 99 Delta: string (nullable = true)
#  |-- glogner_gmbh: string (nullable = true)
#  |-- glogner_gmbh Delta: string (nullable = true)
#  |-- kaufland.de - toolskitchen: string (nullable = true)
#  |-- kaufland.de - toolskitchen Delta: string (nullable = true)
#  |-- akkushop: string (nullable = true)
#  |-- akkushop Delta: string (nullable = true)
#  |-- kaufland.de - price-guard: string (nullable = true)
#  |-- kaufland.de - price-guard Delta: string (nullable = true)
#  |-- heine vertriebs-gmbh: string (nullable = true)
#  |-- heine vertriebs-gmbh Delta: string (nullable = true)
#  |-- bts-ersatzteile: string (nullable = true)
#  |-- bts-ersatzteile Delta: string (nullable = true)
#  |-- freizeitland-simon: string (nullable = true)
#  |-- freizeitland-simon Delta: string (nullable = true)
#  |-- allro: string (nullable = true)
#  |-- allro Delta: string (nullable = true)
#  |-- kaufland.de - deine-tante-emma: string (nullable = true)
#  |-- kaufland.de - deine-tante-emma Delta: string (nullable = true)
#  |-- kaufland.de - rodirect: string (nullable = true)
#  |-- kaufland.de - rodirect Delta: string (nullable = true)
#  |-- festoshop: string (nullable = true)
#  |-- festoshop Delta: string (nullable = true)
#  |-- fertig sht-vertrieb ug (haftungsbeschränkt): string (nullable = true)
#  |-- fertig sht-vertrieb ug (haftungsbeschränkt) Delta: string (nullable = true)
#  |-- kaufland.de - voelkner: string (nullable = true)
#  |-- kaufland.de - voelkner Delta: string (nullable = true)
#  |-- shop.biebrach: string (nullable = true)
#  |-- shop.biebrach Delta: string (nullable = true)
#  |-- vietschi-farben.net: string (nullable = true)
#  |-- vietschi-farben.net Delta: string (nullable = true)
#  |-- hbh24online: string (nullable = true)
#  |-- hbh24online Delta: string (nullable = true)
#  |-- iponshop: string (nullable = true)
#  |-- iponshop Delta: string (nullable = true)
#  |-- belion-world: string (nullable = true)
#  |-- belion-world Delta: string (nullable = true)
#  |-- baumarkt-ulstertal: string (nullable = true)
#  |-- baumarkt-ulstertal Delta: string (nullable = true)
#  |-- bhw24: string (nullable = true)
#  |-- bhw24 Delta: string (nullable = true)
#  |-- kaufland.de - rs-tools-shop-fachhandel-deutsch: string (nullable = true)
#  |-- kaufland.de - rs-tools-shop-fachhandel-deutsch Delta: string (nullable = true)
#  |-- kreiller fachhandel: string (nullable = true)
#  |-- kreiller fachhandel Delta: string (nullable = true)
#  |-- hv-store: string (nullable = true)
#  |-- hv-store Delta: string (nullable = true)
#  |-- maisforte ⭐⭐⭐⭐⭐: string (nullable = true)
#  |-- maisforte ⭐⭐⭐⭐⭐ Delta: string (nullable = true)
#  |-- oscar.ehandel: string (nullable = true)
#  |-- oscar.ehandel Delta: string (nullable = true)
#  |-- maschinenhandel-gronau: string (nullable = true)
#  |-- maschinenhandel-gronau Delta: string (nullable = true)
#  |-- bau-shopping24: string (nullable = true)
#  |-- bau-shopping24 Delta: string (nullable = true)
#  |-- lampenwelt: string (nullable = true)
#  |-- lampenwelt Delta: string (nullable = true)
#  |-- eoffice24: string (nullable = true)
#  |-- eoffice24 Delta: string (nullable = true)
#  |-- conworxx gmbh: string (nullable = true)
#  |-- conworxx gmbh Delta: string (nullable = true)
#  |-- Unnamed: 1036: string (nullable = true)
#  |-- filename: string (nullable = false)

# %%
sdf_prices.select(columns).toPandas()
# Out:
#          brand                                     name        date  \
# 0      Starmix                      uCLEAN ADL-1420 EHP  2023-06-24
# 1          SIA                             siaspeed1950  2023-06-24
# 2       Metabo                              metaBOX 215  2023-06-24
# 3       Metabo                    metaBOX 118 Organizer  2023-06-24
# 4      Starmix                            iPulse H-1635  2023-06-24
# ...        ...                                      ...         ...
# 45475       3M    3M 51370 737U Hookit disc P120 150 mm  2023-07-17
# 45476       3M  3M 31651 Cubitron 150mm P120 - 50 stuks  2023-07-17
# 45477    Bosch   19-TLG. HSS-CO SPIRALBOHRERSET, PROBOX  2023-07-17
# 45478    Mirka                            1230 M AFC EU  2023-07-17
# 45479    Mirka                        1025 L PC EU 230V  2023-07-17
#
#       Median (Price) contorion Delta
# 0             369,26            None
# 1              62,34            None
# 2              41,53            None
# 3              59,42            None
# 4            1050,99            None
# ...              ...             ...
# 45475           None            None
# 45476          44,79            None
# 45477          37,67            None
# 45478        1205,80            None
# 45479         355,81            None
#
# [45480 rows x 5 columns]

# %%
sdf_prices_filtered = sdf_prices.select(columns).filter(sdf_prices.brand == "Festool")

# %%
sdf_prices_filtered.toPandas()

# %%
output_path = "gs://lz-gcs/prices/prices_2.csv"
sdf_prices_filtered = sdf_prices_filtered.coalesce(1)
sdf_prices_filtered.write.csv(output_path, header=True, mode="overwrite", sep = ";")
