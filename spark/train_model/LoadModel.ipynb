# %%
from pyspark.ml.fpm import FPGrowthModel

# %%
# Load the FP-Growth model
loaded_model = FPGrowthModel.load("gs://lz-gcs/fp_growth_assets")

# %%
loaded_model
# Out:
# FPGrowthModel: uid=FPGrowth_de816bc43e06, numTrainingRecords=17

# %%
loaded_model.associationRules.toPandas()
# Out:
#    antecedent  consequent  confidence  lift   support
# 0  [00575781]  [00575302]        1.00  3.40  0.176471
# 1  [00561136]  [00571805]        1.00  4.25  0.176471
# 2  [00571805]  [00561136]        0.75  4.25  0.176471
# 3  [00575302]  [00575781]        0.60  3.40  0.176471
